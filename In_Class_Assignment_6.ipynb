# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/In_Class_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
play = input("Do you want to play a game (y/n)? ")

while play == 'y':
  player = input("Choose b/w rock, paper, scissors: ").lower()
  computer = random.choice(['rock', 'paper', 'scissors'])

  if player == computer:
    print("Draw")
  elif ((player == "rock" and computer == "scissors") or
   (player == "scissors" and computer == "paper") or
   (player == "paper" and computer == "rock")):
    print("Player wins!")
  else:
    print("Computer wins!")
  play = input("Do you want to keep playing? (y/n): ")
# Out:
# Do you want to play a game (y/n)? y
# Choose b/w rock, paper, scissors: rock
# Draw
# Do you want to keep playing? (y/n): y
# Choose b/w rock, paper, scissors: paper
# Draw
# Do you want to keep playing? (y/n): y
# Choose b/w rock, paper, scissors: paper
# Player wins!
# Do you want to keep playing? (y/n): y
# Choose b/w rock, paper, scissors: scissors
# Computer wins!
# Do you want to keep playing? (y/n): n
