# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/In_Class_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = []
num = int(input("Enter a number (enter 0 to stop): "))
while num != 0:
 numbers.append(num)
 num = int(input("Enter a number (enter 0 to stop): "))


numbers.sort(reverse=True)
print("Your numbers in descending order:", numbers)
# Out:
# Enter a number (enter 0 to stop): 8
# Enter a number (enter 0 to stop): 17
# Enter a number (enter 0 to stop): 05
# Enter a number (enter 0 to stop): 6
# Enter a number (enter 0 to stop): 4
# Enter a number (enter 0 to stop): 0
# Your numbers in descending order: [17, 8, 6, 5, 4]

# %%
weights = [10,9.9,10.1,10.05]
print(sum(weights)/len(weights))
print(max(weights))
# Out:
# 10.0125
# 10.1

# %%
a = [1,2,3]
b = a
print(a, b)
# Out:
# [1, 2, 3] [1, 2, 3]

# %%
a = [1,2,3]
b = a[1:4]

a[1] = 10

print(a, b)
# Out:
# [1, 10, 3] [2, 3]
