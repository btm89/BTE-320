# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/In_Class_Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
products = {
    'p-01' : 9.95,
    'p-02' : 10.50
}

id = input("Enter product ID: ")

products.get(id, f"Product {id} does not exist")

if id in products:
  print(f"Price = {product[id]}$")
else:
  print(f"Product {id} does not exist, or is sold out...")
# Out:
# Enter product ID: jkehwfkhjewf
# Product jkehwfkhjewf does not exist, or is sold out...
