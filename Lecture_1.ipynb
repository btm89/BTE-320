# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/Lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+3.0
# Out:
# 8.0

# %%
5-10
# Out:
# -5

# %%
2*3
# Out:
# 6

# %%
6/4
# Out:
# 1.5

# %%
6/4
# Out:
# 1.5

# %%
6//4
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
5%3
# Out:
# 2

# %%
3%4
# Out:
# 3

# %%
3.14*3**2
# Out:
# 28.26

# %%
3<5
# Out:
# True

# %%
4==3
# Out:
# False

# %%
4!=5
# Out:
# True

# %%
b='business technology class'

# %%
name = 5

# %%
cntr = 0

cnt = cntr + 1

cntr += 1
cntr -= 1
cntr *= 1

# %%
True
False

# %%
and

or

not
# Out:
#   File "/tmp/ipython-input-2834528028.py", line 1
#     and
#     ^
# SyntaxError: invalid syntax

# %%
a = True
b = True

a and b
# Out:
# True

# %%
a = False
b = True

a or b
# Out:
# True

# %%
a = False
b = False

a or b
# Out:
# False

# %%
a = False

not a
# Out:
# True

# %%
pi = 3.14
radius = 3

pi * radius ** 2
# Out:
# 28.26

# %%
class2026 = 'abc'
2026class = 5
# Out:
#   File "/tmp/ipython-input-1746277786.py", line 2
#     2026class = 5
#        ^
# SyntaxError: invalid decimal literal

# %%
studentloan = 90
studentloan = 90
student_loan = 90
student loan = 90
# Out:
#   File "/tmp/ipython-input-2356528242.py", line 4
#     student loan = 90
#             ^
# SyntaxError: invalid syntax

# %%
x = 5

x = 'abc'

# %%
type(x)
# Out:
# str

# %%
isinstance(x,str)
# Out:
# True

# %%
isinstance (x, (int, float, str))
# Out:
# True

# %%
x = 3
y = 4

# %%
x, y = 3, 4
