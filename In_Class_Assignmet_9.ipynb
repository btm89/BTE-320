# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/In_Class_Assignmet_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {}

while True:
  name = input("Enter a name: ")
  if name == "":
    break
  if name in names:
    names[name] += 1
  else:
    names[name] = 1

print(names)
# Out:
# Enter a name: Bob
# Enter a name: ALice
# Enter a name: Bob
# Enter a name: Sam
# Enter a name:
# {'Bob': 2, 'ALice': 1, 'Sam': 1}
