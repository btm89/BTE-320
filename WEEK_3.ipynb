# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/WEEK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
email = "Open this link: https:://www.spam.org to receive your award!!!"
is_urgent = "URGENT"
has_www = "www."

if is_urgent in email:
  print("Phishing!")

elif has_www in email:
  print("Spam")

else:
  print("Legit")
# Out:
# Spam

# %%
if condition:
  exprs
  exprs
elif another_condition:
  exprs
  exprs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2833297375.py in <cell line: 0>()
# ----> 1 if condition:
#       2   exprs
#       3   exprs
#       4 elif another_condition:
#       5   exprs
#
# NameError: name 'condition' is not defined

# %%
grade = float(input("Enter student grade (0-100): "))

if grade >= 93:
  print("A")

elif grade >= 97:
  print("A+")
# Out:
# Enter student grade (0-100): 99
# A
