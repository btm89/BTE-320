# %% [markdown]
# <a href="https://colab.research.google.com/github/btm89/BTE-320/blob/main/In_Class_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hour Fee")
for hour in range (1,9):
  fee = 5 + 2.5 * hour
  if fee < 10.0:
    fee = 10.0
  elif fee > 20:
    fee = 20

  print(f"{hour}        {fee}")
# Out:
# Hour Fee
# 1        10.0
# 2        10.0
# 3        12.5
# 4        15.0
# 5        17.5
# 6        20.0
# 7        20
# 8        20
